# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
import random
import os

# %%
df1 = "new data/2020_data_id.csv"
df_2020 = pd.read_csv(df1)
df_2020.head()
# Out:
#       video_id                                              title  \
# 0  4gr_lUXydH4  Back to Hogwarts Global Celebration 2020 hoste...
# 1  rRSm5r1Fjrw        Brandy and Monica go head-to-head in Verzuz
# 2  jUsUzbmSLow                 SuperM 슈퍼엠 ‘호랑이 (Tiger Inside)’ MV
# 3  U0ivaisQoRI  Dani Mocanu 🍒 Costi - Ciresica | Official Vide...
# 4  EOuLt3WWcY0  When the king takes a piano lesson in medieval...
#
#             publishedAt                 channelId     channelTitle  \
# 0  2020-09-01T10:24:18Z  UChPRO1CB_Hvd0TvKRU62iSQ  Wizarding World
# 1  2020-09-01T03:13:35Z  UCqISR0F9-nCth-V2r4Qy75Q        REVOLT TV
# 2  2020-09-01T04:00:11Z  UCEf_Bc-KVd7onSeifS3py9g           SMTOWN
# 3  2020-09-01T07:00:11Z  UC7F3aaccZ4D64ZCrzkCmANw      Dani Mocanu
# 4  2020-09-01T03:28:42Z  UCnZx--LpG2spgmlxOcC-DRA  Daniel Thrasher
#
#    categoryId         trending_date  \
# 0           1  2020-09-01T00:00:00Z
# 1          10  2020-09-01T00:00:00Z
# 2          10  2020-09-01T00:00:00Z
# ...

# %%
df2 = "new data/2022_data_id.csv"
df_2022 = pd.read_csv(df2)
df_2022.head()
# Out:
#       video_id                                              title  \
# 0  xmtQjz_GoEI  Reaction on my fight against KSI & reaction to...
# 1  j5uAR9w7LBg  Nicki Minaj - Super Freaky Girl (Official Musi...
# 2  0TZwLniFkpg                   KSI Hired Hitmen To Hunt Me Down
# 3  UVzVUDXoi0Y   The 1975 - I'm In Love With You (Official Video)
# 4  8Oy_CwU_aJM                   Finding out I'm PREGNANT! Again!
#
#             publishedAt                 channelId  channelTitle  categoryId  \
# 0  2022-09-01T19:00:17Z  UCgnaSY-3eqv8ECG9GHTxdKA        Swarmz          22
# 1  2022-09-01T19:00:08Z  UC3jOd7GUMhpgJRBhiLzuLsg   Nicki Minaj          10
# 2  2022-09-01T16:30:33Z  UCTSCvnsxOcoknftrqdXQzyg  TheBurntChip          24
# 3  2022-09-01T18:00:11Z  UCH_YpPVrF7Kzjew8rB2cdjg   The1975VEVO          10
# 4  2022-09-01T16:03:16Z  UCtPqR1gumPRaMLhSTlLn5nw  The Herberts          22
#
#           trending_date                                               tags  \
# ...

# %%
frames = [df_2020, df_2022]
  
result = pd.concat(frames)
display(result)
# Out:
#         video_id                                              title  \
# 0    4gr_lUXydH4  Back to Hogwarts Global Celebration 2020 hoste...
# 1    rRSm5r1Fjrw        Brandy and Monica go head-to-head in Verzuz
# 2    jUsUzbmSLow                 SuperM 슈퍼엠 ‘호랑이 (Tiger Inside)’ MV
# 3    U0ivaisQoRI  Dani Mocanu 🍒 Costi - Ciresica | Official Vide...
# 4    EOuLt3WWcY0  When the king takes a piano lesson in medieval...
# ..           ...                                                ...
# 951  F5CAWCsNq1Y  Liz Truss defends the Government's mini-budget...
# 952  usSLCdiRoAw  Bruce Springsteen Announces New Album 'Only Th...
# 953  2h95wF4_qHQ    Pitch Meeting Gets An Upgrade! (feat. Simu Liu)
# 954  c-oylxeH6W4        I’m in the Guinness WORLD RECORD Book 2023!
# 955  yjkDL1A80UI  Hurricane Ian Damage Report at the Freedom Fac...
#
#               publishedAt                 channelId       channelTitle  \
# 0    2020-09-01T10:24:18Z  UChPRO1CB_Hvd0TvKRU62iSQ    Wizarding World
# ...

# %%
result.to_csv('new data/merged_final2.csv', index=False)
